# %% [markdown]
# <a href="https://colab.research.google.com/github/pabbbbbb/HerramientasComputacionalesST/blob/main/5_2_Actividad_Visualizaci%C3%B3n_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Actividad
#
# - **Pablo Rodarte**:
# - **A00827746**:
# - **Monir Saade Castillo**:
# - **A00829380**:
# - **Giancarlo Figueroa**
# - **A00828604**
#
# # Entregar
# Archivo PDF de la actividad y la liga de la actividad en su repostitorio.
#
# # Nota:
# Todas las tareas entregadas fuera de la fecha limite se califican sobre 50 de los 100 puntos posibles.

# %%
# Si trabajamos en Google Colaboratory corremos las siguientes lineas de código
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Nos cambiamos a la carpeta donde tengamos el repositorio
# %cd 'drive/MyDrive/SemanaTec/Repos/arte-analitica'
# Out:
# /content/drive/MyDrive/SemanaTec/Repos/arte-analitica

# %% [markdown]
# # Highway MPG dataset
#
# Este dataset contiene variables medidas por la agencia de protección ambiental de 38 modelos de vehículo diferentes de 1999 a 2008. Las variables que se registraron fueron:
#
# * **manufacturer**: nombre del fabricante.
# * **model**: nombre del modelo.
# * **displ**: desplacamiento del motor, en litros.
# * **year**: año de fabricación.
# * **cyl**: número de cilindros.
# * **trans**: tipo de transmisión.
# * **drv**: tipo de tracción, f-delantera, r-trasera, 4- 4 llantas
# * **cty**: rendimiento del motor en ciudad, en millas por galón.
# * **hwy**: rendimiento del motor en carretera, en millas por galón.
# * **fl**: tipo de combustible.
# * **class**: tipo de vehículo.

# %%
# Carga las librerías y datos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

dfo = pd.read_csv("data/auto-mpg.csv")

dfo.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
# ¿Cuántas observaciones hay de cada fabricante? Muéstralo en un gráfico.
datos = dfo
fig = plt.figure(figsize=(20,7))

sns.histplot(data=datos, x="manufacturer", bins=10)

# %%
# Haz un histograma de las variables numéricas cty, hwy y haz una comparación en un gráfico lado a lado

fig, axs = plt.subplots(1,2, figsize=(15, 5))

sns.histplot(data = dfo, x='cty', ax=axs[0])

sns.histplot(data = dfo, x='hwy', ax=axs[1])

# %% [markdown]
# *Mayor rendimiendto general en carretera*

# %%
# ¿Cómo se comparar el rendimiento en carretera (hwy) contra el número de cilindros? 
# Haz un gráfico que represente esta relación.
fig = plt.figure(figsize=(10,5))
sns.scatterplot(data = dfo, y='hwy', x='cyl')

# %%
# cyl es una variable numérica, pero como tiene pocos valores podemos tomarla como si fuera categórica.
# ¿De qué otra forma se puede representar la relación de la pregunta anterior?
fig = plt.figure(figsize=(8, 6))
sns.boxplot(data=dfo, y="hwy", x="cyl")

# %%
# Cuál es la relación entre el desplazamiento del motor y el rendimiento dentro de la ciudad?
fig = plt.figure(figsize=(8,6))
sns.scatterplot(data = dfo, x='displ', y='cty')

# %%
# ¿Cómo se correlacionan las variables numéricas? Muestra esta correlación en un gráfico. (No tomar en cuenta el año como
# variable numérica)

# Sugerencia: usa la paleta de colores 'vlag' o una paleta DIVERGENTE

corr_matrix = dfo.loc[:, ["displ",'cty','hwy','cyl']].corr()

sns.heatmap(data=corr_matrix, cmap = 'vlag')

# %%
matrizc = dfo.drop("year",axis=1).corr()
matrizc
# Out:
#           displ       cyl       cty       hwy
# displ  1.000000  0.930227 -0.798524 -0.766020
# cyl    0.930227  1.000000 -0.805771 -0.761912
# cty   -0.798524 -0.805771  1.000000  0.955916
# hwy   -0.766020 -0.761912  0.955916  1.000000

# %% [markdown]
# *Matriz Correlación*

# %%
# ¿Cuales variables tienen una fuerte relación positiva entre sí y cuáles tienen una fuerte relación negativa?

# %% [markdown]
# *Heat Map muestra la respuesta*
#
# *Positiva: Desplazamiento del motor con cilindros.*
#
# *Negativa: Rendimientos en ciudad y carretera respecto al número de cilindros*

# %%
# ¿Los fabricantes mejoran el rendimiento en ciudad conforme pasa el tiempo? Haz una tabla resumen por año y por marca del
# rendimiento promedio y grafica los resultados.


x1 = dfo.query('manufacturer=="audi"')['year']
y1 = dfo.query('manufacturer=="audi"')['cty']

x2 = dfo.query('manufacturer=="chevrolet"')['year']
y2 = dfo.query('manufacturer=="chevrolet"')['cty']

x3 = dfo.query('manufacturer=="dodge"')['year']
y3 = dfo.query('manufacturer=="dodge"')['cty']

x4 = dfo.query('manufacturer=="ford"')['year']
y4 = dfo.query('manufacturer=="ford"')['cty']

x5 = dfo.query('manufacturer=="honda"')['year']
y5 = dfo.query('manufacturer=="honda"')['cty']

x6 = dfo.query('manufacturer=="hyundai"')['year']
y6 = dfo.query('manufacturer=="hyundai"')['cty']

x7 = dfo.query('manufacturer=="jeep"')['year']
y7 = dfo.query('manufacturer=="jeep"')['cty']

x8 = dfo.query('manufacturer=="land rover"')['year']
y8 = dfo.query('manufacturer=="land rover"')['cty']

x9 = dfo.query('manufacturer=="lincoln"')['year']
y9 = dfo.query('manufacturer=="lincoln"')['cty']

x10 = dfo.query('manufacturer=="mercury"')['year']
y10 = dfo.query('manufacturer=="mercury"')['cty']

x11 = dfo.query('manufacturer=="nissan"')['year']
y11 = dfo.query('manufacturer=="nissan"')['cty']

x12 = dfo.query('manufacturer=="pontiac"')['year']
y12 = dfo.query('manufacturer=="pontiac"')['cty']

x13 = dfo.query('manufacturer=="subaru"')['year']
y13 = dfo.query('manufacturer=="subaru"')['cty']

x14 = dfo.query('manufacturer=="toyota"')['year']
y14 = dfo.query('manufacturer=="toyota"')['cty']

x15 = dfo.query('manufacturer=="volkswagen"')['year']
y15 = dfo.query('manufacturer=="volkswagen"')['cty']

fig = plt.figure(figsize=(15,8))

plt.plot(x1, y1, label='audi')
plt.plot(x2, y2, label='chevrolet')
plt.plot(x3, y3, label='dodge')
plt.plot(x4, y4, label='ford')
plt.plot(x5, y5, label='honda')
plt.plot(x6, y6, label='hyundai')
plt.plot(x7, y7, label='jeep')
plt.plot(x8, y8, label='land rover')
plt.plot(x9, y9, label='lincoln')
plt.plot(x10, y10, label='mercury')
plt.plot(x11, y11, label='nissan')
plt.plot(x12, y12, label='pontiac')
plt.plot(x13, y13, label='subaru')
plt.plot(x14, y14, label='toyota')
plt.plot(x15, y15, label='volkswagen')


plt.xlabel("Año")
plt.ylabel("Rendimiento Ciudad")
plt.legend(loc='best')
